# %%
import re

# %%
text = "Paul Newman was as American actor, but Paul Hollywood is a British TV Host. The name Paul is quite common."

# %%
pattern = r"Paul [A-Z]\w+"

# %%
matches = re.finditer(pattern, text)

# %%
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(0, 11), match='Paul Newman'>
# <re.Match object; span=(39, 53), match='Paul Hollywood'>

# %%
import spacy

# %%
from spacy.tokens import Span

# %%
nlp = spacy.blank("en")
doc = nlp(text)
# Out:
# Paul Newman PERSON
# Paul Hollywood PERSON

# %%
for ent in mwt_ents:
    print(ent)
# Out:
# (0, 2, 'Paul Newman')
# (8, 10, 'Paul Hollywood')

# %%
from spacy.language import Language

# %%
@Language.component("paul_ner")
def paul_ner(doc):
    pattern = r"Paul [A-Z]\w+"
    original_ents = list(doc.ents)
    mwt_ents = []
    for match in re.finditer(pattern, text):
        start, end = match.span()
        span = doc.char_span(start, end)
        if span is not None:
            mwt_ents.append((span.start, span.end, span.text))
    for ent in mwt_ents:
        start, end, name = ent
        per_ent = Span(doc, start, end, label="PERSON")
        original_ents.append(per_ent)
    doc.ents = original_ents
    return (doc)

# %%
nlp2 = spacy.blank("en")
nlp2.add_pipe("paul_ner")
# Out:
# <function __main__.paul_ner(doc)>

# %%
doc2 = nlp2(text)

# %%
print(doc2.ents)
# Out:
# (Paul Newman, Paul Hollywood)

# %%
from spacy.language import Language
from spacy.util import filter_spans
@Language.component("cinema_ner")
def cinema_ner(doc):
    pattern = r"Hollywood"
    original_ents = list(doc.ents)
    mwt_ents = []
    for match in re.finditer(pattern, doc.text):
        start, end = match.span()
        span = doc.char_span(start, end)
        if span is not None:
            mwt_ents.append((span.start, span.end, span.text))
    for ent in mwt_ents:
        start, end, name = ent
        per_ent = Span(doc, start, end, label="CINEMA")
        original_ents.append(per_ent)
    filtered = filter_spans(original_ents)
    doc.ents = filtere
    return (doc)

# %%
nlp3 = spacy.load("en_core_web_sm")
nlp3.add_pipe("cinema_ner")
# Out:
# <function __main__.cinema_ner(doc)>

# %%
doc3 = nlp3(text)
for ent in doc3.ents:
    print(ent.text, ent.label_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 doc3 = nlp3(text)
#       2 for ent in doc3.ents:
#       3     print(ent.text, ent.label_)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\spacy\language.py:1057, in Language.__call__(self, text, disable, component_cfg)
#    1055     raise ValueError(Errors.E109.format(name=name)) from e
#    1056 except Exception as e:
# -> 1057     error_handler(name, proc, [doc], e)
#    1058 if not isinstance(doc, Doc):
#    1059     raise ValueError(Errors.E005.format(name=name, returned_type=type(doc)))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\spacy\util.py:1722, in raise_error(proc_name, proc, docs, e)
#    1721 def raise_error(proc_name, proc, docs, e):
# -> 1722     raise e
#
# File ~\AppData\Roaming\Python\Python312\site-packages\spacy\language.py:1052, in Language.__call__(self, text, disable, component_cfg)
#    1050     error_handler = proc.get_error_handler()
#    1051 try:
# -> 1052     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1053 except KeyError as e:
#    1054     # This typically happens if a component is not initialized
#    1055     raise ValueError(Errors.E109.format(name=name)) from e
#
# Cell In[31], line 18, in cinema_ner(doc)
#      16     original_ents.append(per_ent)
#      17 filtered = filter_spans(original_ents)
# ---> 18 doc.ents = original_ents
#      19 return (doc)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\spacy\tokens\doc.pyx:798, in spacy.tokens.doc.Doc.ents.__set__()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\spacy\tokens\doc.pyx:835, in spacy.tokens.doc.Doc.set_ents()
#
# ValueError: [E1010] Unable to set entity information for token 9 which is included in more than one span in entities, blocked, missing or outside.
