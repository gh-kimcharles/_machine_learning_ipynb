# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
with open (r"C:/Users/pc/Documents/A My Program/A Machine Learning/NLP/st-peter-basilica.txt", encoding="utf-8") as f:
    text = f.read()

# %%
spb_doc = nlp(text) # my doc/file

# %%
for sent in spb_doc.sents: # my sentence in spb_doc
    print(sent)
# Out:
# The Papal Basilica of Saint Peter in the Vatican City (Italian: Basilica Papale di San Pietro in Citta di Vaticano), or simply Saint Peter's Basilica (Latin: Basilica Sancti Petri; Italian: Basilica di San Pietro [baˈziːlika di sam ˈpjɛːtro]), is a church of the Italian High Renaissance located in Vatican City, an independent microstate enclaved within the city of Rome, Italy.
# It was initially planned in the 15th century by Pope Nicholas V and then Pope Julius II to replace the ageing Old St. Peter's Basilica, which was built in the fourth century by Roman emperor Constantine the Great.
# Construction of the present basilica began on 18 April 1506 and was completed on 18 November 1626.[3]
#
# ...

# %%
sentence1 = list(doc.sents)[0] # get the first sentence.
print(sentence1)
# Out:
# The Papal Basilica of Saint Peter in the Vatican City (Italian: Basilica Papale di San Pietro in Citta di Vaticano), or simply Saint Peter's Basilica (Latin: Basilica Sancti Petri; Italian: Basilica di San Pietro [baˈziːlika di sam ˈpjɛːtro]), is a church of the Italian High Renaissance located in Vatican City, an independent microstate enclaved within the city of Rome, Italy.

# %%
for token in sentence1: #get word, PoS, dep in first sentence (sentence1)
    print(token.text, token.pos_, token.dep_)
# Out:
# The DET det
# Papal PROPN compound
# Basilica PROPN nsubj
# of ADP prep
# Saint PROPN compound
# Peter PROPN pobj
# in ADP prep
# the DET det
# Vatican PROPN compound
# City PROPN pobj
# ( PUNCT punct
# Italian PROPN appos
# : PUNCT punct
# Basilica PROPN compound
# Papale PROPN compound
# di X compound
# San PROPN compound
# Pietro PROPN appos
# in ADP prep
# Citta PROPN compound
# di X compound
# Vaticano PROPN pobj
# ) PUNCT punct
# , PUNCT punct
# or CCONJ cc
# simply ADV advmod
# Saint PROPN compound
# Peter PROPN poss
# 's PART case
# Basilica PROPN conj
# ( PUNCT punct
# Latin PROPN appos
# : PUNCT punct
# Basilica PROPN compound
# Sancti PROPN compound
# Petri PROPN appos
# ; PUNCT punct
# Italian ADJ appos
# : PUNCT punct
# Basilica PROPN nmod
# di X compound
# San PROPN compound
# Pietro PROPN appos
# [ X punct
# baˈziːlika X nmod
# di X nmod
# sam PROPN compound
# ˈpjɛːtro PROPN appos
# ] PUNCT punct
# ) PUNCT punct
# , PUNCT punct
# is AUX ROOT
# a DET det
# ...

# %%
from spacy import displacy

# %%
displacy.render(sentence1, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d2a8568ee2f14fb281ffa109a8aaaca7-0" class="displacy" width="10725" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Papal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
# ...

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# The Papal Basilica of Saint Peter ORG
# the Vatican City LOC
# Italian NORP
# Basilica Papale di PERSON
# Saint Peter's PERSON
# Basilica PERSON
# Latin NORP
# Italian NORP
# Basilica di San Pietro PERSON
# di sam ˈpjɛːtro PERSON
# Italian NORP
# Vatican City GPE
# Rome GPE
# Italy GPE

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Papal Basilica of Saint Peter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Vatican City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  (
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Italian
# ...
